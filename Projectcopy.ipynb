# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
file_to_load = "Data/StudentsPerformance.csv"

# %%
ny_df= pd.read_csv(file_to_load)

# %%
ny_df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78
# 6               completed          88             95             92
# 7                    none          40             43             39
# 8               completed          64             64             67
# 9                    none          38             60             50

# %%
ny_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 43.0+ KB

# %%
# histogram to compare math scores of entire population
plt.hist( ny_df['math score'])
plt.title('Math Score', fontdict = {'fontsize': 15})
plt.xlabel('Students', fontdict = {'fontsize': 13})
plt.ylabel('Score', fontdict = {'fontsize': 13})
plt.show()

# %%
#histogram to compare reading score of entire population 
plt.hist( ny_df['reading score'])
plt.title('Reading Score', fontdict = {'fontsize': 15})
plt.xlabel('Students', fontdict = {'fontsize': 13})
plt.ylabel('Score', fontdict = {'fontsize': 13})
plt.show()

# %%
#histogram to compare writing score of entire population
plt.hist( ny_df['writing score'])
plt.title('Writing Score', fontdict = {'fontsize': 15})
plt.xlabel('Students', fontdict = {'fontsize': 13})
plt.ylabel('Score', fontdict = {'fontsize': 13})
plt.show()

# %%
ny_df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
median1 = ny_df['math score'].median()
median1
# Out:
# 66.0

# %%
median2 = ny_df['reading score'].median()
median2
# Out:
# 70.0

# %%
median3 = ny_df['writing score'].median()
median3
# Out:
# 69.0

# %%
ny_df.groupby(['math score']).nunique()
# Out:
#             gender  race/ethnicity  parental level of education  lunch  \
# math score
# 0                1               1                            1      1
# 8                1               1                            1      1
# 18               1               1                            1      1
# 19               1               1                            1      1
# 22               1               1                            1      1
# ...            ...             ...                          ...    ...
# 96               2               1                            2      1
# 97               2               5                            4      1
# 98               2               2                            2      1
# 99               2               1                            3      1
# 100              2               3                            3      2
#
#             test preparation course  math score  reading score  writing score
# math score
# 0                                 1           1              1              1
# 8                                 1           1              1              1
# 18                                1           1              1              1
# 19                                1           1              1              1
# 22                                1           1              1              1
# ...                             ...         ...            ...            ...
# 96                                1           1              3              3
# 97                                2           1              6              6
# 98                                2           1              3              2
# 99                                2           1              3              3
# 100                               2           1              4              5
#
# [81 rows x 8 columns]

# %%
ny_df.groupby(['parental level of education']).count()
# Out:
#                              gender  race/ethnicity  lunch  \
# parental level of education
# associate's degree              222             222    222
# bachelor's degree               118             118    118
# high school                     196             196    196
# master's degree                  59              59     59
# some college                    226             226    226
# some high school                179             179    179
#
#                              test preparation course  math score  \
# parental level of education
# associate's degree                               222         222
# bachelor's degree                                118         118
# high school                                      196         196
# master's degree                                   59          59
# some college                                     226         226
# some high school                                 179         179
#
#                              reading score  writing score
# parental level of education
# associate's degree                     222            222
# bachelor's degree                      118            118
# high school                            196            196
# master's degree                         59             59
# some college                           226            226
# some high school                       179            179

# %%
#mean scores of entire population 
mean_scores = ny_df.groupby(['parental level of education','lunch','test preparation course'],as_index=False).mean()
mean_scores
# Out:
#    parental level of education         lunch test preparation course  \
# 0           associate's degree  free/reduced               completed
# 1           associate's degree  free/reduced                    none
# 2           associate's degree      standard               completed
# 3           associate's degree      standard                    none
# 4            bachelor's degree  free/reduced               completed
# 5            bachelor's degree  free/reduced                    none
# 6            bachelor's degree      standard               completed
# 7            bachelor's degree      standard                    none
# 8                  high school  free/reduced               completed
# 9                  high school  free/reduced                    none
# 10                 high school      standard               completed
# 11                 high school      standard                    none
# 12             master's degree  free/reduced               completed
# 13             master's degree  free/reduced                    none
# 14             master's degree      standard               completed
# 15             master's degree      standard                    none
# 16                some college  free/reduced               completed
# 17                some college  free/reduced                    none
# 18                some college      standard               completed
# 19                some college      standard                    none
# 20            some high school  free/reduced               completed
# 21            some high school  free/reduced                    none
# 22            some high school      standard               completed
# 23            some high school      standard                    none
#
#     math score  reading score  writing score
# 0    68.482759      73.310345      73.310345
# 1    59.062500      64.229167      61.625000
# 2    73.660377      77.735849      78.735849
# 3    68.967391      69.750000      68.043478
# 4    66.764706      73.823529      75.705882
# 5    60.629630      65.851852      65.148148
# 6    77.103448      78.448276      80.448276
# 7    70.666667      73.466667      72.888889
# 8    60.000000      65.458333      65.541667
# 9    51.652174      57.478261      53.152174
# 10   68.750000      69.625000      69.937500
# 11   65.563830      66.372340      63.659574
# 12   65.666667      74.166667      76.500000
# 13   56.666667      66.416667      63.250000
# 14   78.000000      84.375000      85.500000
# 15   74.925926      77.222222      77.925926
# 16   60.730769      68.961538      69.384615
# 17   59.830189      63.169811      60.924528
# 18   76.921569      79.568627      80.156863
# 19   67.687500      67.697917      67.052083
# 20   57.869565      66.000000      65.565217
# 21   51.552632      56.552632      52.815789
# 22   70.462963      73.055556      72.407407
# 23   66.734375      68.281250      65.468750

# %%
#combined mean scores of the entire student population
mean_scores['combined scores'] = (mean_scores['math score'] + mean_scores['reading score'] + mean_scores['writing score']) / 3

# %%
mean_scores
# Out:
#    parental level of education         lunch test preparation course  \
# 0           associate's degree  free/reduced               completed
# 1           associate's degree  free/reduced                    none
# 2           associate's degree      standard               completed
# 3           associate's degree      standard                    none
# 4            bachelor's degree  free/reduced               completed
# 5            bachelor's degree  free/reduced                    none
# 6            bachelor's degree      standard               completed
# 7            bachelor's degree      standard                    none
# 8                  high school  free/reduced               completed
# 9                  high school  free/reduced                    none
# 10                 high school      standard               completed
# 11                 high school      standard                    none
# 12             master's degree  free/reduced               completed
# 13             master's degree  free/reduced                    none
# 14             master's degree      standard               completed
# 15             master's degree      standard                    none
# 16                some college  free/reduced               completed
# 17                some college  free/reduced                    none
# 18                some college      standard               completed
# 19                some college      standard                    none
# 20            some high school  free/reduced               completed
# 21            some high school  free/reduced                    none
# 22            some high school      standard               completed
# 23            some high school      standard                    none
#
#     math score  reading score  writing score  combined scores
# 0    68.482759      73.310345      73.310345        71.701149
# 1    59.062500      64.229167      61.625000        61.638889
# 2    73.660377      77.735849      78.735849        76.710692
# 3    68.967391      69.750000      68.043478        68.920290
# 4    66.764706      73.823529      75.705882        72.098039
# 5    60.629630      65.851852      65.148148        63.876543
# 6    77.103448      78.448276      80.448276        78.666667
# 7    70.666667      73.466667      72.888889        72.340741
# 8    60.000000      65.458333      65.541667        63.666667
# 9    51.652174      57.478261      53.152174        54.094203
# 10   68.750000      69.625000      69.937500        69.437500
# 11   65.563830      66.372340      63.659574        65.198582
# 12   65.666667      74.166667      76.500000        72.111111
# 13   56.666667      66.416667      63.250000        62.111111
# 14   78.000000      84.375000      85.500000        82.625000
# 15   74.925926      77.222222      77.925926        76.691358
# 16   60.730769      68.961538      69.384615        66.358974
# 17   59.830189      63.169811      60.924528        61.308176
# 18   76.921569      79.568627      80.156863        78.882353
# 19   67.687500      67.697917      67.052083        67.479167
# 20   57.869565      66.000000      65.565217        63.144928
# 21   51.552632      56.552632      52.815789        53.640351
# 22   70.462963      73.055556      72.407407        71.975309
# 23   66.734375      68.281250      65.468750        66.828125

# %%
#dataframe with mean combined scores of advantaged population 
advantaged_df = mean_scores[(mean_scores['parental level of education'].isin(["bachelor's degree" ,"master's degree"])) & (mean_scores['lunch'].isin(['standard'])) & (mean_scores['test preparation course'].isin(['completed']))]

# %%
advantaged_df
# Out:
#    parental level of education     lunch test preparation course  math score  \
# 6            bachelor's degree  standard               completed   77.103448
# 14             master's degree  standard               completed   78.000000
#
#     reading score  writing score  combined scores
# 6       78.448276      80.448276        78.666667
# 14      84.375000      85.500000        82.625000

# %%
#dataframe with mean combined scores of disadvantaged population
disadvantaged_df = mean_scores[(mean_scores['parental level of education'].isin(['high school' ,'some high school', 'some college', "associate's degree"])) & (mean_scores['lunch'].isin(['standard','free/reduced'])) & (mean_scores['test preparation course'].isin(['completed','none']))]

# %%
disadvantaged_df
# Out:
#    parental level of education         lunch test preparation course  \
# 0           associate's degree  free/reduced               completed
# 1           associate's degree  free/reduced                    none
# 2           associate's degree      standard               completed
# 3           associate's degree      standard                    none
# 8                  high school  free/reduced               completed
# 9                  high school  free/reduced                    none
# 10                 high school      standard               completed
# 11                 high school      standard                    none
# 16                some college  free/reduced               completed
# 17                some college  free/reduced                    none
# 18                some college      standard               completed
# 19                some college      standard                    none
# 20            some high school  free/reduced               completed
# 21            some high school  free/reduced                    none
# 22            some high school      standard               completed
# 23            some high school      standard                    none
#
#     math score  reading score  writing score  combined scores
# 0    68.482759      73.310345      73.310345        71.701149
# 1    59.062500      64.229167      61.625000        61.638889
# 2    73.660377      77.735849      78.735849        76.710692
# 3    68.967391      69.750000      68.043478        68.920290
# 8    60.000000      65.458333      65.541667        63.666667
# 9    51.652174      57.478261      53.152174        54.094203
# 10   68.750000      69.625000      69.937500        69.437500
# 11   65.563830      66.372340      63.659574        65.198582
# 16   60.730769      68.961538      69.384615        66.358974
# 17   59.830189      63.169811      60.924528        61.308176
# 18   76.921569      79.568627      80.156863        78.882353
# 19   67.687500      67.697917      67.052083        67.479167
# 20   57.869565      66.000000      65.565217        63.144928
# 21   51.552632      56.552632      52.815789        53.640351
# 22   70.462963      73.055556      72.407407        71.975309
# 23   66.734375      68.281250      65.468750        66.828125

# %%
#combining dataframes of students with parents who have bachelor and master degrees to create advantaged data frame
bachelor_population = ny_df[(ny_df['parental level of education'] == 'bachelor\'s degree') & (ny_df.lunch == "standard") & 
      (ny_df['test preparation course'] == 'completed')]

master_populaton = ny_df[(ny_df['parental level of education'] == 'master\'s degree') & (ny_df.lunch == "standard") & 
      (ny_df['test preparation course'] == 'completed')]
combine_advantage_population =[bachelor_population,master_populaton]
advantage_population = pd.concat(combine_advantage_population)

# %%
#mean combined score of the advantaged population
advantage_population['Combined Scores'] = (advantage_population['math score'] + advantage_population['reading score'] + advantage_population['writing score']) / 3
round(advantage_population,2)
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 77     male        group A           bachelor's degree  standard
# 101    male        group D           bachelor's degree  standard
# 114  female        group E           bachelor's degree  standard
# 120  female        group C           bachelor's degree  standard
# 148  female        group D           bachelor's degree  standard
# 165  female        group C           bachelor's degree  standard
# 234    male        group C           bachelor's degree  standard
# 312    male        group D           bachelor's degree  standard
# 314  female        group C           bachelor's degree  standard
# 347  female        group C           bachelor's degree  standard
# 416    male        group C           bachelor's degree  standard
# 464    male        group A           bachelor's degree  standard
# 475  female        group D           bachelor's degree  standard
# 476    male        group E           bachelor's degree  standard
# 538    male        group E           bachelor's degree  standard
# 562    male        group C           bachelor's degree  standard
# 594  female        group C           bachelor's degree  standard
# 595  female        group C           bachelor's degree  standard
# 612    male        group C           bachelor's degree  standard
# 632  female        group B           bachelor's degree  standard
# 645  female        group B           bachelor's degree  standard
# 700  female        group E           bachelor's degree  standard
# 702    male        group A           bachelor's degree  standard
# 784    male        group C           bachelor's degree  standard
# 880    male        group C           bachelor's degree  standard
# 881  female        group E           bachelor's degree  standard
# 909    male        group E           bachelor's degree  standard
# 912  female        group C           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 175  female        group C             master's degree  standard
# 194  female        group C             master's degree  standard
# 316  female        group D             master's degree  standard
# 410  female        group D             master's degree  standard
# 685  female        group E             master's degree  standard
# 812  female        group C             master's degree  standard
# 846    male        group C             master's degree  standard
# 995  female        group E             master's degree  standard
#
#     test preparation course  math score  reading score  writing score  \
# 77                completed          80             78             81
# 101               completed          68             74             74
# 114               completed          99            100            100
# 120               completed          79             92             89
# 148               completed          68             75             81
# 165               completed          96            100            100
# 234               completed          83             82             84
# 312               completed          67             61             68
# 314               completed          59             64             75
# 347               completed          77             94             95
# 416               completed          71             74             68
# 464               completed          75             58             62
# 475               completed          71             76             83
# 476               completed          76             62             66
# 538               completed          85             66             71
# 562               completed          96             90             92
# 594               completed          92            100             99
# 595               completed          56             79             72
# 612               completed          94             90             91
# 632               completed          66             74             81
# 645               completed          65             81             81
# 700               completed          79             81             82
# 702               completed          87             84             87
# 784               completed          91             81             79
# 880               completed          63             64             66
# 881               completed          71             70             70
# 909               completed          70             64             70
# 912               completed          52             61             66
# 916               completed         100            100            100
# 175               completed          81             91             87
# 194               completed          69             84             85
# 316               completed          77             82             91
# 410               completed          70             71             74
# 685               completed          94             99            100
# 812               completed          54             64             67
# 846               completed          91             85             85
# 995               completed          88             99             95
#
#      Combined Scores
# 77             79.67
# 101            72.00
# 114            99.67
# 120            86.67
# 148            74.67
# 165            98.67
# 234            83.00
# 312            65.33
# 314            66.00
# 347            88.67
# 416            71.00
# 464            65.00
# 475            76.67
# 476            68.00
# 538            74.00
# 562            92.67
# 594            97.00
# 595            69.00
# 612            91.67
# 632            73.67
# 645            75.67
# 700            80.67
# 702            86.00
# 784            83.67
# 880            64.33
# 881            70.33
# 909            68.00
# 912            59.67
# 916           100.00
# 175            86.33
# 194            79.33
# 316            83.33
# 410            71.67
# 685            97.67
# 812            61.67
# 846            87.00
# 995            94.00

# %%
#data frame of disadvantaged population
disadvantage_population = ny_df[(ny_df['parental level of education'].isin(['high school' ,'some high school', 'some college', "associate's degree"])) & (ny_df['lunch'].isin(['standard','free/reduced'])) & (ny_df['test preparation course'].isin(['completed','none']))]
disadvantage_population
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 1                 completed          69             90             88
# 3                      none          47             57             44
# 4                      none          76             78             75
# 5                      none          71             83             78
# 6                 completed          88             95             92
# ..                      ...         ...            ...            ...
# 994                    none          63             63             62
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [823 rows x 8 columns]

# %%
#combining the scores of disadvantaged population 
disadvantage_population['Combined Scores'] = (disadvantage_population['math score'] + disadvantage_population['reading score'] + disadvantage_population['writing score']) / 3
round(disadvantage_population,2)
# Out:
# c:\users\abifabi\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 1                 completed          69             90             88
# 3                      none          47             57             44
# 4                      none          76             78             75
# 5                      none          71             83             78
# 6                 completed          88             95             92
# ..                      ...         ...            ...            ...
# 994                    none          63             63             62
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      Combined Scores
# 1              82.33
# 3              49.33
# 4              76.33
# 5              77.33
# 6              91.67
# ..               ...
# 994            62.67
# 996            57.33
# 997            65.00
# 998            74.33
# 999            83.00
#
# [823 rows x 9 columns]

# %%
#Dataframe of students whos parents have a higher level of education but have free/reduced lunch
partial_advantage1 = mean_scores[(mean_scores['parental level of education'].isin(["master's degree", "bachelor's degree"])) & (mean_scores['lunch'].isin(['free/reduced'])) & (mean_scores['test preparation course'].isin(['completed','none']))]
partial_advantage1.head(50)
# Out:
#    parental level of education         lunch test preparation course  \
# 4            bachelor's degree  free/reduced               completed
# 5            bachelor's degree  free/reduced                    none
# 12             master's degree  free/reduced               completed
# 13             master's degree  free/reduced                    none
#
#     math score  reading score  writing score  combined scores
# 4    66.764706      73.823529      75.705882        72.098039
# 5    60.629630      65.851852      65.148148        63.876543
# 12   65.666667      74.166667      76.500000        72.111111
# 13   56.666667      66.416667      63.250000        62.111111

# %%
#partial population1 are students whos parents have a higher level of education, had free/reduced lunch but were able to complete lunch 
partial_population1 = ny_df[(ny_df['parental level of education'].isin(["master's degree", "bachelor's degree"])) & (ny_df['lunch'].isin(['free/reduced'])) & (ny_df['test preparation course'].isin(['completed','none']))]
partial_population1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 32   female        group E             master's degree  free/reduced
# 60     male        group E           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 910    male        group D           bachelor's degree  free/reduced
# 913  female        group C           bachelor's degree  free/reduced
# 933    male        group C           bachelor's degree  free/reduced
# 940    male        group C             master's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 18                completed          46             42             46
# 24                completed          74             71             80
# 25                     none          73             74             72
# 32                     none          56             72             65
# 60                completed          79             74             72
# ..                      ...         ...            ...            ...
# 910                    none          50             42             48
# 913               completed          47             62             66
# 933               completed          70             75             74
# 940               completed          72             66             72
# 993                    none          62             72             74
#
# [68 rows x 8 columns]

# %%
partial_population1['Combined Scores'] = (partial_population1['math score'] + partial_population1['reading score'] + partial_population1['writing score']) / 3
round(partial_population1,2)
# Out:
# c:\users\abifabi\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      gender race/ethnicity parental level of education         lunch  \
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 32   female        group E             master's degree  free/reduced
# 60     male        group E           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 910    male        group D           bachelor's degree  free/reduced
# 913  female        group C           bachelor's degree  free/reduced
# 933    male        group C           bachelor's degree  free/reduced
# 940    male        group C             master's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 18                completed          46             42             46
# 24                completed          74             71             80
# 25                     none          73             74             72
# 32                     none          56             72             65
# 60                completed          79             74             72
# ..                      ...         ...            ...            ...
# 910                    none          50             42             48
# 913               completed          47             62             66
# 933               completed          70             75             74
# 940               completed          72             66             72
# 993                    none          62             72             74
#
#      Combined Scores
# 18             44.67
# 24             75.00
# 25             73.00
# 32             64.33
# 60             75.00
# ..               ...
# 910            46.67
# 913            58.33
# 933            73.00
# 940            70.00
# 993            69.33
#
# [68 rows x 9 columns]

# %%
#partial advantage2 is students whos parents have higher level of education, have standard lunch but did not complete test prep
partial_advantage2 = mean_scores[(mean_scores['parental level of education'].isin(["master's degree", "bachelor's degree"])) & (mean_scores['lunch'].isin(['standard'])) & (mean_scores['test preparation course'].isin(['none']))]
partial_advantage2
# Out:
#    parental level of education     lunch test preparation course  math score  \
# 7            bachelor's degree  standard                    none   70.666667
# 15             master's degree  standard                    none   74.925926
#
#     reading score  writing score  combined scores
# 7       73.466667      72.888889        72.340741
# 15      77.222222      77.925926        76.691358

# %%
partial_population2 = ny_df[(ny_df['parental level of education'].isin(["master's degree", "bachelor's degree"])) & (ny_df['lunch'].isin(['standard'])) & (ny_df['test preparation course'].isin(['none']))]
partial_population2
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 2    female        group B             master's degree  standard
# 14   female        group A             master's degree  standard
# 27   female        group C           bachelor's degree  standard
# 29   female        group D             master's degree  standard
# ..      ...            ...                         ...       ...
# 901  female        group C             master's degree  standard
# 941  female        group D             master's degree  standard
# 957  female        group D             master's degree  standard
# 969  female        group B           bachelor's degree  standard
# 970  female        group D           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 2                      none          90             95             93
# 14                     none          50             53             58
# 27                     none          67             69             75
# 29                     none          62             70             75
# ..                      ...         ...            ...            ...
# 901                    none          73             78             74
# 941                    none          78             91             96
# 957                    none          92            100            100
# 969                    none          75             84             80
# 970                    none          89            100            100
#
# [72 rows x 8 columns]

# %%
partial_population2['Combined Scores'] = (partial_population2['math score'] + partial_population2['reading score'] + partial_population2['writing score']) / 3
round(partial_population2,2)
# Out:
# c:\users\abifabi\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 2    female        group B             master's degree  standard
# 14   female        group A             master's degree  standard
# 27   female        group C           bachelor's degree  standard
# 29   female        group D             master's degree  standard
# ..      ...            ...                         ...       ...
# 901  female        group C             master's degree  standard
# 941  female        group D             master's degree  standard
# 957  female        group D             master's degree  standard
# 969  female        group B           bachelor's degree  standard
# 970  female        group D           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 2                      none          90             95             93
# 14                     none          50             53             58
# 27                     none          67             69             75
# 29                     none          62             70             75
# ..                      ...         ...            ...            ...
# 901                    none          73             78             74
# 941                    none          78             91             96
# 957                    none          92            100            100
# 969                    none          75             84             80
# 970                    none          89            100            100
#
#      Combined Scores
# 0              72.67
# 2              92.67
# 14             53.67
# 27             70.33
# 29             69.00
# ..               ...
# 901            75.00
# 941            88.33
# 957            97.33
# 969            79.67
# 970            96.33
#
# [72 rows x 9 columns]

# %%
#mean score of partial advantage group 1
partial_advantage1 = mean_scores[(mean_scores['parental level of education'].isin(["master's degree", "bachelor's degree"])) & (mean_scores['lunch'].isin(['free/reduced'])) & (mean_scores['test preparation course'].isin(['completed','none']))]
partial_advantage1.head(50)
# Out:
#    parental level of education         lunch test preparation course  \
# 4            bachelor's degree  free/reduced               completed
# 5            bachelor's degree  free/reduced                    none
# 12             master's degree  free/reduced               completed
# 13             master's degree  free/reduced                    none
#
#     math score  reading score  writing score  combined scores
# 4    66.764706      73.823529      75.705882        72.098039
# 5    60.629630      65.851852      65.148148        63.876543
# 12   65.666667      74.166667      76.500000        72.111111
# 13   56.666667      66.416667      63.250000        62.111111

# %%
# mean score of partial advatnage 2 
partial_advantage2 = mean_scores[(mean_scores['parental level of education'].isin(["master's degree", "bachelor's degree"])) & (mean_scores['lunch'].isin(['standard','free/reduced'])) & (mean_scores['test preparation course'].isin(['none']))]
partial_advantage2.head(50)
# Out:
#    parental level of education         lunch test preparation course  \
# 5            bachelor's degree  free/reduced                    none
# 7            bachelor's degree      standard                    none
# 13             master's degree  free/reduced                    none
# 15             master's degree      standard                    none
#
#     math score  reading score  writing score  combined scores
# 5    60.629630      65.851852      65.148148        63.876543
# 7    70.666667      73.466667      72.888889        72.340741
# 13   56.666667      66.416667      63.250000        62.111111
# 15   74.925926      77.222222      77.925926        76.691358

# %%
# combining disadvantaged population, and partial 1 and partial 2 
combined_disadvantage=[disadvantaged_df,partial_advantage1,partial_advantage2]
combined_mean_score = pd.concat(combined_disadvantage)

# %%
combined_disadvantage_pop = [disadvantage_population,partial_population1,partial_population2]
no_advantage_population = pd.concat(combined_disadvantage_pop)

# %%
no_advantage_population
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 901  female        group C             master's degree      standard
# 941  female        group D             master's degree      standard
# 957  female        group D             master's degree      standard
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 1                 completed          69             90             88
# 3                      none          47             57             44
# 4                      none          76             78             75
# 5                      none          71             83             78
# 6                 completed          88             95             92
# ..                      ...         ...            ...            ...
# 901                    none          73             78             74
# 941                    none          78             91             96
# 957                    none          92            100            100
# 969                    none          75             84             80
# 970                    none          89            100            100
#
#      Combined Scores
# 1          82.333333
# 3          49.333333
# 4          76.333333
# 5          77.333333
# 6          91.666667
# ..               ...
# 901        75.000000
# 941        88.333333
# 957        97.333333
# 969        79.666667
# 970        96.333333
#
# [963 rows x 9 columns]

# %%
#combined population of disadvantaged students, and students with partial advanatges 
combined_mean_score
# Out:
#    parental level of education         lunch test preparation course  \
# 0           associate's degree  free/reduced               completed
# 1           associate's degree  free/reduced                    none
# 2           associate's degree      standard               completed
# 3           associate's degree      standard                    none
# 8                  high school  free/reduced               completed
# 9                  high school  free/reduced                    none
# 10                 high school      standard               completed
# 11                 high school      standard                    none
# 16                some college  free/reduced               completed
# 17                some college  free/reduced                    none
# 18                some college      standard               completed
# 19                some college      standard                    none
# 20            some high school  free/reduced               completed
# 21            some high school  free/reduced                    none
# 22            some high school      standard               completed
# 23            some high school      standard                    none
# 4            bachelor's degree  free/reduced               completed
# 5            bachelor's degree  free/reduced                    none
# 12             master's degree  free/reduced               completed
# 13             master's degree  free/reduced                    none
# 5            bachelor's degree  free/reduced                    none
# 7            bachelor's degree      standard                    none
# 13             master's degree  free/reduced                    none
# 15             master's degree      standard                    none
#
#     math score  reading score  writing score  combined scores
# 0    68.482759      73.310345      73.310345        71.701149
# 1    59.062500      64.229167      61.625000        61.638889
# 2    73.660377      77.735849      78.735849        76.710692
# 3    68.967391      69.750000      68.043478        68.920290
# 8    60.000000      65.458333      65.541667        63.666667
# 9    51.652174      57.478261      53.152174        54.094203
# 10   68.750000      69.625000      69.937500        69.437500
# 11   65.563830      66.372340      63.659574        65.198582
# 16   60.730769      68.961538      69.384615        66.358974
# 17   59.830189      63.169811      60.924528        61.308176
# 18   76.921569      79.568627      80.156863        78.882353
# 19   67.687500      67.697917      67.052083        67.479167
# 20   57.869565      66.000000      65.565217        63.144928
# 21   51.552632      56.552632      52.815789        53.640351
# 22   70.462963      73.055556      72.407407        71.975309
# 23   66.734375      68.281250      65.468750        66.828125
# 4    66.764706      73.823529      75.705882        72.098039
# 5    60.629630      65.851852      65.148148        63.876543
# 12   65.666667      74.166667      76.500000        72.111111
# 13   56.666667      66.416667      63.250000        62.111111
# 5    60.629630      65.851852      65.148148        63.876543
# 7    70.666667      73.466667      72.888889        72.340741
# 13   56.666667      66.416667      63.250000        62.111111
# 15   74.925926      77.222222      77.925926        76.691358

# %%
sample1 = advantaged_df['combined scores']
sample1
# Out:
# 6     78.666667
# 14    82.625000
# Name: combined scores, dtype: float64

# %%
sample2 = combined_mean_score['combined scores']
sample2
# Out:
# 0     71.701149
# 1     61.638889
# 2     76.710692
# 3     68.920290
# 8     63.666667
# 9     54.094203
# 10    69.437500
# 11    65.198582
# 16    66.358974
# 17    61.308176
# 18    78.882353
# 19    67.479167
# 20    63.144928
# 21    53.640351
# 22    71.975309
# 23    66.828125
# 4     72.098039
# 5     63.876543
# 12    72.111111
# 13    62.111111
# 5     63.876543
# 7     72.340741
# 13    62.111111
# 15    76.691358
# Name: combined scores, dtype: float64

# %%
combine_sample1 = advantage_population['Combined Scores']

# %%
combine_sample2 = no_advantage_population['Combined Scores']

# %%
t2, p2 = stats.ttest_ind(sample1, sample2)
print("t = " + str(t2))
print("p = " + str(p2))
# Out:
# t = 2.921020300041413
# p = 0.007480838632764154

# %%
def gendata(loc1=0, loc2=0):
    sample1 = advantaged_df['combined scores']
    sample2 = disadvantaged_df['combined scores']
fig = plt.figure(figsize = (12,10))    
plt.subplot(2, 1, 1)
plt.scatter(range(len(sample1)), sample1, label="Advantaged")
plt.scatter(range(len(sample2)), sample2, label="Not Advantaged")
plt.legend()
plt.title('Advantaged vs Disadvantaged', fontdict = {'fontsize': 15})
plt.savefig('scatterplot.png')
#return sample1, sample2

# %%
# plt.hist([x, y], bins, label=['x', 'y'])
# plt.legend(loc='upper right')

plt.hist([combine_sample1,combine_sample2], alpha=0.5, label=['Advantaged','Not Advantaged'])
plt.legend(loc='upper right')
plt.xlabel('Actual Scores', fontdict = {'fontsize': 13})
plt.ylabel('Number of Students', fontdict = {'fontsize': 13})
plt.show()

# %%
fig = plt.figure(figsize = (12,10))
plt.subplot(2, 1, 2)
plt.hist([combine_sample1,combine_sample2], density=True, alpha=0.7, label=["Advantaged","Not Advantaged"])
# plt.hist(combine_sample2, 5, density=True, alpha=0.7, label="Not Advantaged")
# plt.axvline(sample1.mean(), color='k', linestyle='dashed', linewidth=1)
# plt.axvline(sample2.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()
plt.title('Advantaged vs Not Advantaged', fontdict = {'fontsize': 15})
plt.xlabel('Percentile of Students', fontdict = {'fontsize': 13})
plt.ylabel('percentile of Scores', fontdict = {'fontsize': 13})
plt.savefig('disvsadvsubplot.png')

# %%
math_sample1 = advantaged_df['math score']
math_sample1.mean()
# Out:
# 77.55172413793103

# %%
math_sample2 = combined_mean_score["math score"]
math_sample2.mean()
# Out:
# 64.18938125061572

# %%
reading_sample1 = advantaged_df['reading score']
reading_sample1.mean()
# Out:
# 81.41163793103448

# %%
reading_sample2 = combined_mean_score["reading score"]
reading_sample2.mean()
# Out:
# 68.76928117575365

# %%
writing_sample1 = advantaged_df['writing score']
writing_sample1.mean()
# Out:
# 82.97413793103448

# %%
writing_sample2 = combined_mean_score["writing score"]
writing_sample2 .mean()
# Out:
# 67.81657644559318

# %%
combine_sample1.mean()
# Out:
# 79.52252252252251

# %%
combine_sample2.mean()
# Out:
# 67.31914157147803
